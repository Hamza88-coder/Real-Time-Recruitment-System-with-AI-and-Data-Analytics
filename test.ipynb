# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.efficientnet import preprocess_input

# Charger une image exemple (remplacez le chemin par celui de votre image)
image_path = "th.jpg"  # Remplacez par le chemin de votre image
image = tf.keras.utils.load_img(image_path, target_size=(224, 224))  # Taille attendue pour EfficientNet
image_array = tf.keras.utils.img_to_array(image)

# Visualiser l'image d'origine
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image_array.astype("uint8"))  # Conversion en uint8 pour l'affichage
plt.title("Image Originale")
plt.axis("off")

# Appliquer le prétraitement
preprocessed_image = preprocess_input(image_array)

# Afficher l'image prétraitée (normalisée pour affichage)
plt.subplot(1, 2, 2)
plt.imshow((preprocessed_image - preprocessed_image.min()) / (preprocessed_image.max() - preprocessed_image.min()))
plt.title("Image Prétraitée (Normalisée)")
plt.axis("off")

plt.show()

# Vérifier les valeurs avant et après le prétraitement
print("Valeurs avant prétraitement :")
print("Min :", image_array.min(), "| Max :", image_array.max())

print("Valeurs après prétraitement :")
print("Min :", preprocessed_image.min(), "| Max :", preprocessed_image.max())
# Out:
# Valeurs avant prétraitement :
# Min : 0.0 | Max : 255.0
# Valeurs après prétraitement :
# Min : 0.0 | Max : 255.0
